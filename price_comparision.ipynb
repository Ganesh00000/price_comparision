# %% [markdown]
# <a href="https://colab.research.google.com/github/Ganesh00000/price_comparision/blob/main/price_comparision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %%
import requests
from bs4 import BeautifulSoup
import smtplib

# %%
url="https://www.amazon.in/Matte-Storage-Additional-Exchange-Offers/dp/B089MV6MGW/ref=sr_1_1_sspa?dchild=1&keywords=oppo+reno+3&qid=1603209730&sr=8-1-spons&psc=1&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUEyVFFGREg0U0MzTklQJmVuY3J5cHRlZElkPUEwODM2NjkyQ0k3VEhCRk9LREVYJmVuY3J5cHRlZEFkSWQ9QTAwOTI1NTZGUVBNNTRQR1RETUomd2lkZ2V0TmFtZT1zcF9hdGYmYWN0aW9uPWNsaWNrUmVkaXJlY3QmZG9Ob3RMb2dDbGljaz10cnVl"

# %%
headers={"user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36"}

# %%
page=requests.get(url,headers=headers)

# %%
soup=BeautifulSoup(page.content,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
print(soup.title)
# Out:
# <title>OPPO F17 Pro (Matte Black, 8GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers: Amazon.in: Electronics</title>

# %%
print(soup.title.name)
# Out:
# title

# %%
print(soup.title.string)
# Out:
# OPPO F17 Pro (Matte Black, 8GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers: Amazon.in: Electronics

# %%
print(soup.p)
# Out:
# <p>Delivery Associate will place the order on your doorstep and step back to maintain a 2-meter distance.</p>

# %%
print(soup.find_all("p"))
# Out:
# [<p>Delivery Associate will place the order on your doorstep and step back to maintain a 2-meter distance.</p>, <p>No customer signatures are required at the time of delivery.</p>, <p>For Pay-on-Delivery orders, we recommend paying using Credit card/Debit card/Netbanking via the pay-link sent via SMS at the time of delivery. To pay by cash, place cash on top of the delivery box and step back.</p>, <p><a href="/b/ref=amb_link_1/259-0175279-9072160?ie=UTF8&amp;node=22159860031&amp;pf_rd_m=A1VBAL9TL5WCBF&amp;pf_rd_s=hero-quick-promo&amp;pf_rd_r=S4N2RZEZMRSPSR69PB0T&amp;pf_rd_r=S4N2RZEZMRSPSR69PB0T&amp;pf_rd_t=201&amp;pf_rd_p=9cd87845-e029-4b26-a03c-6a59ee60a85b&amp;pf_rd_p=9cd87845-e029-4b26-a03c-6a59ee60a85b&amp;pf_rd_i=B089MV6MGW" target="_blank"><b>Sign in/Create a free business account </b></a></p>, <p class="a-spacing-small a-size-small a-color-secondary" id="askDPSearchPromptLabel">
#         Find answers in product info, Q&amp;As, reviews
# ...

# %%
for paragraph in soup.find_all("p"):
  print(paragraph.string)
  print(str(paragraph.text))
# Out:
# Delivery Associate will place the order on your doorstep and step back to maintain a 2-meter distance.
# Delivery Associate will place the order on your doorstep and step back to maintain a 2-meter distance.
# No customer signatures are required at the time of delivery.
# No customer signatures are required at the time of delivery.
# For Pay-on-Delivery orders, we recommend paying using Credit card/Debit card/Netbanking via the pay-link sent via SMS at the time of delivery. To pay by cash, place cash on top of the delivery box and step back.
# For Pay-on-Delivery orders, we recommend paying using Credit card/Debit card/Netbanking via the pay-link sent via SMS at the time of delivery. To pay by cash, place cash on top of the delivery box and step back.
# Sign in/Create a free business account
# Sign in/Create a free business account
#
#         Find answers in product info, Q&As, reviews
#
#
#         Find answers in product info, Q&As, reviews
#
#
# ...

# %%
for url in soup.find_all("a"):
  print(url.get("href"))
# Out:
# None
# None
# /gp/site-directory?ref_=nav_em_js_disabled
# /ref=nav_logo
# /gp/customer-preferences/select-language/ref=topnav_lang?preferencesReturnUrl=%2F
# https://www.amazon.in/ap/signin?openid.pape.max_auth_age=0&openid.return_to=https%3A%2F%2Fwww.amazon.in%2FMatte-Storage-Additional-Exchange-Offers%2Fdp%2FB089MV6MGW%2Fref%3Dsr_1_1_sspa%2F%3F_encoding%3DUTF8%26dchild%3D1%26keywords%3Doppo%2520reno%25203%26psc%3D1%26qid%3D1603209730%26spLa%3DZW5jcnlwdGVkUXVhbGlmaWVyPUEyVFFGREg0U0MzTklQJmVuY3J5cHRlZElkPUEwODM2NjkyQ0k3VEhCRk9LREVYJmVuY3J5cHRlZEFkSWQ9QTAwOTI1NTZGUVBNNTRQR1RETUomd2lkZ2V0TmFtZT1zcF9hdGYmYWN0aW9uPWNsaWNrUmVkaXJlY3QmZG9Ob3RMb2dDbGljaz10cnVl%26sr%3D8-1-spons%26ref_%3Dnav_ya_signin&openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.assoc_handle=inflex&openid.mode=checkid_setup&openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0&
# ...

# %%
print(soup.get_text())
# Out:
# var aPageStart = (new Date()).getTime();
# var ue_t0=ue_t0||+new Date();
#
#
#
#
#
#
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# (function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||"undefined",logLevel:"WARN"})}}}})(ue_csm);
#
#
#     var ue_err_chan = 'jserr-rw';
# ...

# %%
a=soup.find(id="productTitle")
b=a.get_text()

# %%
print(b.strip())
# Out:
# OPPO F17 Pro (Matte Black, 8GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers

# %%
price=soup.find(id="priceblock_dealprice")

# %%
cp=price.get_text()

# %%
print(cp.strip())
# Out:
# ₹ 22,990.00

# %%
s=cp[-9:]

# %%
print(type(s))
# Out:
# <class 'str'>

# %%
res=requests.get("https://www.flipkart.com/oppo-f17-pro-matte-black-128-gb/p/itm4e2fc7ddc621c?pid=MOBFVYVXMYEUDPTY&lid=LSTMOBFVYVXMYEUDPTYQN71JQ&marketplace=FLIPKART&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_2_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_2_na_na_na&fm=SEARCH&iid=ea22a5de-6af7-4e4a-a14f-3f71d4f0f63d.MOBFVYVXMYEUDPTY.SEARCH&ppt=sp&ppn=sp&ssid=qtc5xby8qo0000001603210225834&qH=c4506a2fec339924")

# %%
soup=BeautifulSoup(res.text,"lxml")

# %%
name=soup.select("._35KyD6")

# %%
price=soup.select("._1vC4OE._3qQ9m1")

# %%
price
# Out:
# [<div class="_1vC4OE _3qQ9m1">₹22,990</div>]

# %%
c=25000.00
d=25200.00

# %%
price=0
company=""

# %%
if c<d:
  price=c
  company="Amazon"
else:
  price=d
  company="flipkart"

# %%
print(price)
print(company)
# Out:
# 25000.0
# Amazon

# %%
def send_mail():
 server=smtplib.SMTP("smtp.gmail.com",587)
 server.starttls()
 server.login("shahgk0000@gmail.com","k@thmandu")
 subject="price fell down"
 if company=="Amazon":
    body="check the amazon link\nhttps://www.amazon.in/Matte-Storage-Additional-Exchange-Offers/dp/B089MV6MGW/ref=sr_1_1_sspa?crid=102RJ7TGOB3Y9&dchild=1&keywords=oppo+f17+pro+mobile+phones&qid=1603212562&sprefix=oppo+%2Caps%2C380&sr=8-1-spons&psc=1&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUEyRTFPOEVKRlo2QVhHJmVuY3J5cHRlZElkPUEwNzc1NTIxM1UxU1ZGVjFCWDdEUCZlbmNyeXB0ZWRBZElkPUEwMDkyNTU2RlFQTTU0UEdURE1KJndpZGdldE5hbWU9c3BfYXRmJmFjdGlvbj1jbGlja1JlZGlyZWN0JmRvTm90TG9nQ2xpY2s9dHJ1ZQ=="
    msg=f"subject:{subject}\n\n{body}"
    server.sendmail(from_addr="shahgk0000@gmail.com",to_addrs="1815991@ggi.ac.in",msg=msg
    )
    print("mail send")
    server.quit()
 else:
    body="check flipkart link\nhttps://www.flipkart.com/oppo-f17-pro-matte-black-128-gb/p/itm4e2fc7ddc621c?pid=MOBFVYVXMYEUDPTY&lid=LSTMOBFVYVXMYEUDPTYQN71JQ&marketplace=FLIPKART&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&fm=SEARCH&iid=f564baf7-d7f8-45d8-b662-28f82e37d1d1.MOBFVYVXMYEUDPTY.SEARCH&ppt=sp&ppn=sp&ssid=4gwzb9ooy80000001603212835351&qH=c4506a2fec339924"
    msg=f"subject:{subject}\n\n{body}"
    server.sendmail(from_addr="shahgk0000@gmail.com",to_addrs="1815991@ggi.ac.in",msg=msg
    )
    print("mail send")
    server.quit()

# %%
send_mail()
# Out:
# mail send
